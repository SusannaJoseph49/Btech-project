# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('combined_data.csv')

# %%
display(df.head())
# Out:
#   Cell_Type   Phase Volume  Phase_Variance  \
# 0       Hek    3309.074158       57.654616
# 1       Hek    3630.107691      923.235217
# 2       Hek   38236.014425    14237.096896
# 3       Hek      52.984288      663.753975
# 4       Hek  224270.162358     7023.222553
#
#    Phase_Surface_Area_to_Volume_Ratio  Phase_Skewness      Dry_Mass  \
# 0                            0.403143        0.342372  1.654537e+04
# 1                            1.130838       -0.288402  1.815054e+04
# 2                            3.787462        1.703172  1.911801e+05
# 3                          209.137328       -0.172664  2.649214e+02
# 4                            1.455073        0.285291  1.121351e+06
#
#    Phase_Sphericity_Index  Phase_Surface_Area_to_Dry_Mass_Ratio   Mean_OPD  \
# 0                0.804988                              0.080629  47.957596
# 1                0.278255                              0.226168  46.539842
# ...

# %%
df.replace([np.inf, -np.inf], np.nan, inplace=True)

# %%
print(df.isnull().sum())
# Out:
# Cell_Type                                0
# Phase Volume                             0
# Phase_Variance                          48
# Phase_Surface_Area_to_Volume_Ratio      22
# Phase_Skewness                          48
# Dry_Mass                                 0
# Phase_Sphericity_Index                  65
# Phase_Surface_Area_to_Dry_Mass_Ratio    22
# Mean_OPD                                 0
# Projected_Area_To_Volume                22
# Phase_Kurtosis                          48
# Energy                                   0
# Median_OPD                               0
# Phase_Surface_Area                       0
# Density                                  0
# dtype: int64

# %%
df = df.dropna()

# %%
print(df.isnull().sum())
# Out:
# Cell_Type                               0
# Phase Volume                            0
# Phase_Variance                          0
# Phase_Surface_Area_to_Volume_Ratio      0
# Phase_Skewness                          0
# Dry_Mass                                0
# Phase_Sphericity_Index                  0
# Phase_Surface_Area_to_Dry_Mass_Ratio    0
# Mean_OPD                                0
# Projected_Area_To_Volume                0
# Phase_Kurtosis                          0
# Energy                                  0
# Median_OPD                              0
# Phase_Surface_Area                      0
# Density                                 0
# dtype: int64

# %%
display(df.describe())
# Out:
#        Phase Volume  Phase_Variance  Phase_Surface_Area_to_Volume_Ratio  \
# count  1.270100e+04    12701.000000                        1.270100e+04
# mean   1.432731e+05     2309.356619                        7.226967e+02
# std    1.602298e+05     2805.658677                        1.623507e+04
# min    5.021440e-02       36.824361                        6.844343e-02
# 25%    1.931137e+04      753.389130                        7.440269e-01
# 50%    1.046342e+05     1336.317637                        1.306144e+00
# 75%    2.081340e+05     2982.527163                        5.511154e+00
# max    2.988205e+06    71035.503986                        1.314639e+06
#
#        Phase_Skewness      Dry_Mass  Phase_Sphericity_Index  \
# count    12701.000000  1.270100e+04            12701.000000
# mean         0.221305  7.163655e+05                0.076960
# std          0.525851  8.011488e+05                0.060122
# min         -7.597107  2.510720e-01                0.000009
# ...

# %%
X = df[['Phase Volume','Phase_Variance','Phase_Surface_Area_to_Volume_Ratio','Phase_Skewness','Dry_Mass','Phase_Sphericity_Index','Phase_Surface_Area_to_Dry_Mass_Ratio','Mean_OPD','Projected_Area_To_Volume','Phase_Kurtosis','Energy','Median_OPD','Phase_Surface_Area','Density']]
y = df['Cell_Type']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
rf_classifier = RandomForestClassifier(n_estimators=100, random_state=42)
rf_classifier.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred = rf_classifier.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
class_report = classification_report(y_test, y_pred)

# %%
print(f"Accuracy: {accuracy:.4f}")
print("Confusion Matrix:")
print(conf_matrix)
print("Classification Report:")
print(class_report)
# Out:
# Accuracy: 0.9845
# Confusion Matrix:
# [[1566   44]
#  [  15 2186]]
# Classification Report:
#               precision    recall  f1-score   support
#
#         A375       0.99      0.97      0.98      1610
#          Hek       0.98      0.99      0.99      2201
#
#     accuracy                           0.98      3811
#    macro avg       0.99      0.98      0.98      3811
# weighted avg       0.98      0.98      0.98      3811
